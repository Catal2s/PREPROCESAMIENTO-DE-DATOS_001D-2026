# %%
In [1]: %load_ext kedro.ipython
# Out:
# The kedro.ipython extension is already loaded. To reload it, use:
#   %reload_ext kedro.ipython

# %%
##hacer analisis exploratorio, a los 3 archivos
##subirlo a github,
##hacer un git commit, en el visual.
companies = catalog.load("companies")
companies.head()
# Out:
# [03/19/26 15:27:57] INFO     Loading data from companies (CSVDataset)...                       ]8;id=629929;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=693998;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating        company_location  total_fleet_count  \
# 0   3888           100%             Isle of Man                1.0
# 1  46728           100%                     NaN                1.0
# 2  34618            38%             Isle of Man                1.0
# 3  28619           100%  Bosnia and Herzegovina                1.0
# 4   8240            NaN                   Chile                1.0
#
#   iata_approved
# 0             f
# 1             f
# ...

# %%
shuttles=catalog.load("shuttles")
shuttles.head()
# Out:
# [03/19/26 15:29:33] INFO     Loading data from shuttles (ExcelDataset)...                      ]8;id=411371;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=699635;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1  49438      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2  10750                   Niue      Type F5     Quantum  ThetaBase Services
# 3   4146                  Malta      Type V2     Quantum  ThetaBase Services
# 4   5067                  Malta      Type V2      Plasma  ThetaBase Services
#
# ...

# %%
reviews=catalog.load("reviews")
reviews.head()
# Out:
# [03/19/26 15:30:17] INFO     Loading data from reviews (CSVDataset)...                         ]8;id=60968;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=499031;file://C:\Users\Pavillion\AppData\Local\Programs\Python\Python313\Lib\site-packages\kedro\io\data_catalog.py#1048\1048]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    shuttle_id  review_scores_rating  review_scores_comfort  \
# 0       45163                  91.0                   10.0
# 1       49438                  96.0                   10.0
# 2       10750                  97.0                   10.0
# 3        4146                  95.0                   10.0
# 4        5067                  97.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# ...
